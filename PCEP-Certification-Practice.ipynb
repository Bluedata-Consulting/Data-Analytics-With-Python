# %%
#Q.1
#Nested Loops
for i in range(3): #3 will be exclusive 
    for j in range(2): #2 will be exclusive 
        print(i,j)
# Out:
# 0 0
# 0 1
# 1 0
# 1 1
# 2 0
# 2 1

# %%
#Q.2
#How many times will the loop run in this code? - Ans: 5 times
i=0
while i<5:
    i=i+1
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
#Q.3
#Lists
my_list=[1,2,3,4,5,6]
my_list.append(5) #will add an element at the end of the list
print(my_list)
# Out:
# [1, 2, 3, 4, 5, 6, 5]

# %%
#Q.4
#Lists
list1=[1,2,3,4,5]
list2=[8,9,10]
list1.extend(list2) #will add multiple elements at the end of the list 

print(list1)
# Out:
# [1, 2, 3, 4, 5, 8, 9, 10]

# %%
#How is insert() different from append() - 
#How is insert() similar to append() -

# %%
#Q.5
#Tuple
my_tup=(1,2,3)
my_tup[0]=4

print(my_tup)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 4
#       1 #Q.5
#       2 #Tuple
#       3 my_tup=(1,2,3)
# ----> 4 my_tup[0]=4
#       6 print(my_tup)
#
# TypeError: 'tuple' object does not support item assignment

# %%
#Q.6
#Strings
s="Hello World!"
print(s[7:12])
# Out:
# orld!

# %%
#Q.7
#Datatypes
x=10
y="5"
print(x+int(y))
# Out:
# 15

# %%
#Q.8
#Datatypes
result=7//2 #integer division 
print(type(result))
# Out:
# <class 'int'>

# %%
#Q.9
#Loops
for i in range(4,1,-1):
    print(i)
# Out:
# 4
# 3
# 2

# %%
#Q.10
#Functions
def greeting(name='John'): #What type of argument? Ans: Default argument 
    print("Hello, Good morning",name)

greeting()
# Out:
# Hello, Good morning John

# %%
#Q.11
#Lists
numbers=[1,2,3,4,1,2,8,1,7,3,8,1,6,0]
print(len(numbers))
# Out:
# 14

# %%
#Q.12
#Dictionaries
d={"a":1,"b":2,"c":3,"d":4}
#Which method(s) will remove a key-value pair from the dictionary Ans: Both B and C
#A) d.remove()
#B) del d[]
#C) d.pop()

# %%
#What is the difference between remove() and pop()?

# %%
#How do you find the position of a substring "World" from "Hello World" ? Ans: Both A and B
#A)using .index()
#B)using .find()

# %%
#Q.13
#Conditional Statements
x=15
y=25

if x>10 and y<30:
    print("Condition 1")
elif x==15 or y==15:
    print("Condition 2")
else:
    print("No conditions satisfied")
# Out:
# Condition 1

# %%
#Q.14
#Loops
n=4
while n>0:
    n=n-1
    if n==2:
        continue #element 2 gets skipped but the iteration is not going to stop
    print(n)
# Out:
# 3
# 1
# 0

# %%
#Q.15
#Functions
def add(a,b):
    return a+b

def multiply(a,b):
    return a*b

result=add(5,multiply(2,3))
print(result)
# Out:
# 11

# %%
#Q.16
#Functions
def outer(x):
    def inner(y):
        return x*y
    return inner

result=outer(5)(2)
print(result)
# Out:
# 10

# %%
#Q.17
#Lists
my_list=[1,2,3,4,5]
my_list[2:4]=[8,9,10]

print(my_list)
# Out:
# [1, 2, 8, 9, 10, 5]

# %%
#Q.18
#Nested Lists
list=[10,20,30,40]
list.insert(2,[50,60])

print(list)
# Out:
# [10, 20, [50, 60], 30, 40]

# %%
#From the above output, write a code to fetch element 60

# %%
list[2][1]
# Out:
# 60

# %%
#Q.19
#Nested List
fruit=["Apple","Kivi","Banana",["Russia","China","India","Myanmar"],"Mango","Grapes","Oranges"]

# %%
fruit[3][0]
# Out:
# 'Russia'

# %%
fruit[3][2:]
# Out:
# ['India', 'Myanmar']

# %%
fruit[5:]
# Out:
# ['Grapes', 'Oranges']

# %%
a=fruit[1:3] #['Kivi', 'Banana']

# %%
b=fruit[3][1:3] #['China', 'India']

# %%
print(a+b)
# Out:
# ['Kivi', 'Banana', 'China', 'India']

# %%
#Q.20
#Dictionaries
d={"a":1,"b":2,"c":3,"d":5,"e":6}
keys_to_remove=[key for key, value in d.items() if value%2==0]
for key in keys_to_remove:
    del d[key]
print(d)
# Out:
# {'a': 1, 'c': 3, 'd': 5}

# %%
name = "Aashutosh"
names=( "Meera", "Aashutosh" )
first_name
